# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e9377372-1962-43a5-95ea-ee8728a92dd6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e9377372-1962-43a5-95ea-ee8728a92dd6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Sweden data.csv')

# %%
df.head()
# Out:
#      X       Y
# 0   23   56.90
# 1   29  121.02
# 2   15   12.32
# 3  222   78.25
# 4  120  777.10
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_16['X'].plot(kind='hist', bins=20, title='X')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['Y'].plot(kind='hist', bins=20, title='Y')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_18.plot(kind='scatter', x='X', y='Y', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       64 non-null     int64
#  1   Y       64 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 1.1 KB

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'X'}>, <Axes: title={'center': 'Y'}>]],
#       dtype=object)

# %%
import matplotlib.pyplot as plt
x=df.iloc[:,:1]
y=df.iloc[:,-1]
plt.scatter(x,y)
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=3)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (54, 1)
# (14, 1)
# (54,)
# (14,)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train, y_train)
prediction1 = lr.predict(x_test)
prediction1_rounded = np.round(prediction1, 2)
print(prediction1_rounded)
# Out:
# [111.95  78.78  76.64  70.22  88.41  84.13  75.57 196.48 120.51 192.2
#   70.22  78.78  68.08 115.16]

# %%
import numpy as np
from sklearn import metrics
rmse1 = np.sqrt(metrics.mean_squared_error(y_test, prediction1))
r2_score1 = metrics.r2_score(y_test, prediction1)
rmse1 = round(rmse1, 2)
r2_score1 = round(r2_score1, 2)
print(rmse1)
print(r2_score1)
# Out:
# 179.14
# 0.23

# %%
score_train = lr.score(x_train, y_train)
score_train = round(score_train, 2)
print(score_train)
# Out:
# 0.24

# %%
plt.scatter(x_train,y_train,color='yellow')
plt.plot(x_train,lr.predict(x_train),color='black')
plt.show()

# %%
plt.scatter(x_test,y_test,color='green')
plt.plot(x_test,lr.predict(x_test),color='orange')
plt.show()

# %%
x_label = [23,29,15,222,120]
y_label = [56.9,121.02,12.32,78.25,777.1]

# %%
plt.bar(x_label, y_label, color='red', alpha=0.5, label='Bar Plot')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Bar Plot')
plt.legend()

# Show the plot
plt.show()
